# %%
from matplotlib import image
import matplotlib.pyplot as plt

# %%
# image released to public domain
img = image.imread("sandbox.png")
print("coucou")
# Out:
# coucou

# %%
plt.figure()
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
img = 1 - img

# %%
plt.figure()
plt.imshow(img)
plt.axis("off")
plt.show()
